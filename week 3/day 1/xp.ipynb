# %% [markdown]
# Exercise 1: Introduction to Data Analysis (Easy)
#
#
# Objective: Understand the basic overview and significance of data analysis.
# Task:
# Write a short essay or report on the following topics:
#
# What is data analysis?
# Why is data analysis important in modern contexts?
# List and describe three areas where data analysis is applied today.
# Hint/Tip:
#
# Research current trends in data analysis and real-world examples to provide depth to your essay.

# %%
Data analysis is the process of inspecting, cleansing, transforming, and modeling data with the goal of discovering useful information, informing conclusions,
and supporting decision-making.  It involves a systematic approach to understanding data, identifying patterns,
and extracting meaningful insights that can be used to solve problems or improve processes.
This can range from simple descriptive statistics to complex predictive modeling using sophisticated algorithms.
In today's data-driven world, data analysis is paramount.  The sheer volume of data generated daily across various sectors makes it
impossible to discern valuable insights without systematic analysis.  Businesses, governments, and researchers alike rely on data analysis to make informed decisions,
improve efficiency, identify opportunities, and mitigate risks.  Essentially, data analysis provides the lens through which we can understand our increasingly complex world,
enabling us to act with knowledge rather than speculation.
Three key areas where data analysis is applied today include:

1. **Business and Marketing:** Data analysis plays a vital role in optimizing marketing campaigns, understanding customer behavior,
and improving sales strategies. Businesses analyze customer demographics, purchase history, website traffic, and social media engagement to create targeted advertising campaigns,
personalize customer experiences, and predict future trends.  For example, e-commerce platforms leverage data analysis to recommend products, optimize pricing,
and personalize website layouts based on individual browsing habits.  This leads to increased customer satisfaction, conversion rates, and overall revenue.
2. **Healthcare:** Data analysis is revolutionizing healthcare through improved diagnostics, personalized treatments, and disease prediction.
Hospitals and research institutions utilize data analysis to analyze patient medical records, genetic information, and clinical trial data to identify disease patterns,
develop new treatments, and predict patient outcomes.  For instance,
analyzing large datasets of patient information can help identify individuals at high risk of developing certain diseases, enabling proactive interventions and early diagnosis.
Additionally, data analysis supports the development of drug discovery and personalized medicine, leading to more effective and tailored treatments.
3. **Finance:**  In the financial sector, data analysis is critical for risk management, fraud detection, and investment strategies.
Financial institutions analyze market trends, transaction patterns, and credit scores to assess risks, identify fraudulent activities,
and make investment decisions.  Algorithmic trading models, powered by data analysis, automate trading processes based on real-time market data,
enabling quicker and potentially more profitable trades. Moreover, credit scoring models utilize data analysis to assess an individual's creditworthiness,
allowing lenders to make more informed decisions about loan approvals and interest rates.

In conclusion, data analysis has become an indispensable tool across various sectors.
Its importance lies in the ability to extract meaningful insights from complex datasets,
facilitating better decision-making, improved processes, and a deeper understanding of our world.
As data generation continues to accelerate, the role of data analysis will only become more crucial in shaping our future.

# %% [markdown]
# 🌟Exercise 2: Dataset Loading and Initial Analysis
#
#
# Objective: Practice dataset loading from Kaggle and initial analysis.
# Task:
# for the following dataset : How Much Sleep Do Americans Really Get?, Global Trends in Mental Health Disorder and Credit Card Approvals.
#
# Load the dataset into Jupyter or Google Colab.
# Display the first few rows.
# Provide a brief dataset description.

# %%
import pandas as pd
try:
  sleep_df = pd.read_csv('3.csv')
  print("Sleep Health Dataset Loaded Successfully")
except FileNotFoundError:
  print("Sleep Health Dataset file not found. Please check the filename or upload the correct dataset.")

try:
  mental_health_df = pd.read_csv('2.csv')
  print("Mental Health Dataset Loaded Successfully")
except FileNotFoundError:
  print("Mental Health Dataset file not found. Please check the filename or upload the correct dataset.")

try:
  credit_df = pd.read_csv('5.csv')
  print("Credit Card Approval Prediction Dataset Loaded Successfully")
except FileNotFoundError:
  print("Credit Card Approval Prediction Dataset file not found. Please check the filename or upload the correct dataset.")
# Display the first few rows of each dataset
print("\nFirst few rows of Sleep Health Dataset:")
print(sleep_df.head())
print("\nFirst few rows of Mental Health Dataset:")
print(mental_health_df.head())
print("\nFirst few rows of Credit Card Approval Dataset:")
print(credit_df.head())
print("\nSleep Health Dataset Description:")
print(sleep_df.info())
print("\nMental Health Dataset Description:")
print(mental_health_df.info())
print("\nCredit Card Approval Prediction Dataset Description:")
print(credit_df.info())
# Out:
# Sleep Health Dataset Loaded Successfully
# Mental Health Dataset Loaded Successfully
# Credit Card Approval Prediction Dataset Loaded Successfully
#
# First few rows of Sleep Health Dataset:
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# 2             0.096692               4.831108                1.694334
# ...

# %% [markdown]
# Exercise 3: Identifying Data Types
#
#
# Objective: Learn to identify different data types.
# Task:
# For the datasets from the previous exercise, categorize each column of it as either quantitative or qualitative and explain your reasoning.

# %%
def identify_data_types(df, df_name):
    """
    Categorizes columns of a DataFrame as quantitative or qualitative.
    """

    print(f"\nData Type Identification for {df_name}:")
    for col in df.columns:
        dtype = df[col].dtype
        if pd.api.types.is_numeric_dtype(df[col]):
            data_type = "Quantitative"
        elif pd.api.types.is_datetime64_any_dtype(df[col]):
          data_type = "Quantitative"
        elif pd.api.types.is_categorical_dtype(df[col]):
            data_type = "Qualitative"
        elif dtype == 'object':
            data_type = "Qualitative"
        else:
            data_type = "Unknown"

        print(f"- Column '{col}': {data_type}")
identify_data_types(sleep_df, "Sleep Health Dataset")
identify_data_types(mental_health_df, "Mental Health Dataset")
identify_data_types(credit_df, "Credit Card Approval Dataset")
# Out:
# Data Type Identification for Sleep Health Dataset:
# - Column 'index': Quantitative
# - Column 'Entity': Qualitative
# - Column 'Code': Qualitative
# - Column 'Year': Qualitative
# - Column 'Schizophrenia (%)': Qualitative
# - Column 'Bipolar disorder (%)': Qualitative
# - Column 'Eating disorders (%)': Qualitative
# - Column 'Anxiety disorders (%)': Quantitative
# - Column 'Drug use disorders (%)': Quantitative
# - Column 'Depression (%)': Quantitative
# - Column 'Alcohol use disorders (%)': Quantitative
#
# Data Type Identification for Mental Health Dataset:
# - Column 'index': Quantitative
# - Column 'Year': Quantitative
# - Column 'Period': Qualitative
# - Column 'Avg hrs per day sleeping': Quantitative
# - Column 'Standard Error': Quantitative
# - Column 'Type of Days': Qualitative
# - Column 'Age Group': Qualitative
# - Column 'Activity': Qualitative
# - Column 'Sex': Qualitative
#
# Data Type Identification for Credit Card Approval Dataset:
# - Column 'Gender': Quantitative
# ...

# %% [markdown]
# Exercise 4: Exploring Data Types
#
#
# Objective: Learn about different types of data in data analysis.
# Task:
# Load the Iris dataset using Kaggle into a Jupyter Notebook or Google Colaboratory Notebook.
# Identify and list which columns in your dataset are qualitative and which are quantitative.
# Write a brief description of why each column is classified as qualitative or quantitative.
# Tools: Jupyter Notebook, Python with Pandas library.

# %%
try:
    iris_df = pd.read_csv('Iris.csv')
    print("Iris Dataset Loaded Successfully")
except FileNotFoundError:
    print("Iris Dataset file not found. Please check the filename or upload the correct dataset.")

def identify_data_types(df, df_name):
    """
    Categorizes columns of a DataFrame as quantitative or qualitative.
    """

    print(f"\nData Type Identification for {df_name}:")
    for col in df.columns:
        dtype = df[col].dtype
        if pd.api.types.is_numeric_dtype(df[col]):
            data_type = "Quantitative"
        elif pd.api.types.is_datetime64_any_dtype(df[col]):
          data_type = "Quantitative"
        elif pd.api.types.is_categorical_dtype(df[col]):
            data_type = "Qualitative"
        elif dtype == 'object':
            data_type = "Qualitative"
        else:
            data_type = "Unknown"

        print(f"- Column '{col}': {data_type}")

identify_data_types(iris_df, "Iris Dataset")
# Out:
# Iris Dataset Loaded Successfully
#
# Data Type Identification for Iris Dataset:
# - Column 'Id': Quantitative
# - Column 'SepalLengthCm': Quantitative
# - Column 'SepalWidthCm': Quantitative
# - Column 'PetalLengthCm': Quantitative
# - Column 'PetalWidthCm': Quantitative
# - Column 'Species': Qualitative
# <ipython-input-8-b8c488dc7c4b>:19: DeprecationWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, pd.CategoricalDtype) instead
#   elif pd.api.types.is_categorical_dtype(df[col]):

# %% [markdown]
# Exercise 5: Basic Data Analysis with Google Colab
#
#
# Objective: Perform basic data analysis using Google Colab.
# Task:
# Using the same notebook from the previous exercise, perform basic data analysis tasks:
# Calculate the mean, median, and mode of a quantitative column.
# Create a simple plot (like a histogram or bar chart) to visualize the data using Matplotlib/Seaborn libraries :
# import matplotlib.pyplot as plt
# plt.plot(data['Name_column1'], data['Name_column2'])
# plt.show()
# Document your findings in the notebook.
# Tools: Google Colab, Python with Pandas and Matplotlib/Seaborn libraries.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
mean_sepal_length = iris_df['SepalLengthCm'].mean()
median_sepal_length = iris_df['SepalLengthCm'].median()
mode_sepal_length = iris_df['SepalLengthCm'].mode()[0]

print(f"Mean Sepal Length: {mean_sepal_length}")
print(f"Median Sepal Length: {median_sepal_length}")
print(f"Mode Sepal Length: {mode_sepal_length}")

plt.figure(figsize=(8, 6))
plt.hist(iris_df['SepalLengthCm'], bins=10, edgecolor='black')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.title('Distribution of Sepal Length')
plt.show()
plt.figure(figsize=(8, 6))
sns.boxplot(x='Species', y='SepalLengthCm', data=iris_df)
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.title('Sepal Length Distribution by Species')
plt.show()
plt.plot(iris_df['SepalLengthCm'], iris_df['SepalWidthCm'])
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Sepal Length vs. Sepal Width')
plt.show()
# Out:
# Mean Sepal Length: 5.843333333333334
# Median Sepal Length: 5.8
# Mode Sepal Length: 5.0

# %% [markdown]
# Exercise 6: Basic Observation Skills in Data Analysis
#
#
# Objective: Develop observation skills for data analysis.
# Task:
# Load the How Much Sleep Do Americans Really Get? dataset into Jupyter or Google Colab.
# Identify columns that could be interesting for a specific type of analysis (e.g., trend analysis, group comparison) and explain your choice.
# Tools: Jupyter Notebook, Python with Pandas library.

# %%
try:
    sleep_df = pd.read_csv('4.csv')
    print("Sleep Health Dataset Loaded Successfully")
except FileNotFoundError:
    print("Sleep Health Dataset file not found. Please check the filename or upload the correct dataset.")
print("\nColumns for Analysis in the Sleep Health Dataset:")
print(sleep_df.columns)
# Out:
# Sleep Health Dataset Loaded Successfully
#
# Columns for Analysis in the Sleep Health Dataset:
# Index(['index', 'Year', 'Period', 'Avg hrs per day sleeping', 'Standard Error',
#        'Type of Days', 'Age Group', 'Activity', 'Sex'],
#       dtype='object')

# %%
The columns `Hours of Sleep` and `Age` from the "How Much Sleep Do Americans Really Get?"
dataset are interesting for several types of analysis:
1.Trend Analysis:Hours of Sleep` over `Age` could reveal trends in sleep patterns across different age groups.
We might observe if sleep duration decreases or increases with age, or if there are specific age brackets with
significantly different sleeping habits.
2.Group Comparison: Comparing `Hours of Sleep` across different age groups (e.g., young adults vs. older adults)
could highlight differences in sleep needs or patterns.  We could group by age ranges and calculate the average sleep duration for
each group.  Further, we can analyze if there is any significant difference between genders.
3.Correlation Analysis:Investigating the correlation between `Hours of Sleep` and other relevant columns like `Exercise` or
Stress Levels` (if available) would provide insight into how lifestyle factors correlate with sleep duration.
4.Regression Analysis:Hours of Sleep could be the dependent variable in a regression model,
and age, along with other relevant features, as independent variables.
This would help to understand the impact of these factors on the number of sleeping hours.
These analyses could help understand the typical sleeping patterns for different demographics and
identify potential factors influencing sleep.
